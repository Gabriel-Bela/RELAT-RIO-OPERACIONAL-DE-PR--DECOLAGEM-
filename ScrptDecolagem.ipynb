# %% [markdown]
# #                            MISSÃO ESPAÇONAVE AURORA-01

# %%
#DEFINIÇÃO DAS VARIAVÉIS DOS SENSORES DA NAVE:

temp_interna : float   # Temperatura Interna         (0 °C a 40°C)
temp_externa : float   # Temperatura Externa         (-20 °C a 50°C)
integridade : bool     # Integridade Estrutural      (1 = Íntegra)
energia : int          # Níveis de Energia           (>=  70%)
press : float          # Pressão dos Tanques         (80% a 100%)
modulos : bool         # Status dos módulos críticos (Todos em "OK")

# %%
#Recebimento dos dados da nave
print ("=== SISTEMA DE VERIFICAÇÃO DA AURORA-1 ===")
temp_interna = float(input("Insira a Temperatura Interna em °C"))
temp_externa = float(input("Insira a Temperatura Externa em °C"))
integridade  = bool(input("Qual a Integridade Estrutural?\n0- Sem integridade \n1-Integro"))
energia      = int(input("Informe o nível de Energia"))
Press        = float(input("Qual é a pressão dos tanques?"))
modulos      = bool(input("Qual o Status dos módulos críticos"))
# Out:
# === SISTEMA DE VERIFICAÇÃO DA AURORA-1 ===

# %%
#verificação das condições de decolagem
if temp_interna >= 0 and temp_interna <=40:
    print("Temperatura perfeita!")
elif temp_interna < 0:
        print("Temperatura muito baixa, abortar decolagem!")   
else: print("Temperatura muito alta, abortar decolagem!")
if temp_externa >= -20 and temp_externa <=50:
# Out:
# Temperatura muito alta, abortar decolagem!
